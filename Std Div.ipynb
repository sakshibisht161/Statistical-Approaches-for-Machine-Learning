# %%
#std div

# %%
x = [1,2,3,4,5]
sm = 0
mean = sum(x)/len(x)
for i in range (len(x)):
  sm = sm + (x[i]-mean)**2
rmse = (sm/len(x))**0.5
print(rmse)
# Out:
# 1.4142135623730951

# %%
x = [5,6,7,8,9]
sm = 0
mean = sum(x)/len(x)
for i in range (len(x)):
  sm = sm + (x[i]-mean)**2
rmse = (sm/len(x))**0.5
print(rmse)
# Out:
# 1.4142135623730951

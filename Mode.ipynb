# %% [markdown]
# MODE

# %%
from statistics import multimode
data = [2,5,5,6,6,6,7]
mode = multimode(data)
print(mode)
# Out:
# [6]

# %%
import statistics
data = [10,20,30,40,50,65]
mean_value = statistics.mean(data)
median_value = statistics.median(data)
print(mean_value)
print(median_value)
# Out:
# 35.833333333333336
# 35.0
